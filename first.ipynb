# %%
import pandas as pd
import numpy as np

# %% [markdown]
#  key Data structre in pandas
# 1.series
# 2.DataFrame -2 dimesonal

# %%
s= pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df= pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie'], 'Marks': [85,56,38]})
df
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     56
# 2  Charlie     38

# %%
import numpy as np

marks = np.array([85, 90, 70])

print(np.mean(marks))
print(np.max(marks))
# Out:
# 81.66666666666667
# 90
